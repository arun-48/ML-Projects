# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, PolynomialFeatures
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
df=pd.read_csv(r"C:\Users\ABISHEK\OneDrive\Desktop\AIML\data.csv")
print("Shape:",df.shape)
print("Columns:", df.columns.tolist())
print("\nMissing values:\n", df.isnull().sum())
print("\nDuplicate rows:\n", df.duplicated().sum())
# Out:
# Shape: (4600, 18)
# Columns: ['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'country']
#
# Missing values:
#  date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64
#
# Duplicate rows:
#  0

# %%
df = df.drop(['date','street','city','statezip','country'], axis=1)

# %%
#step: Handlde miising values
for col in df.select_dtypes(include=['int64','float64']).columns:
    df[col].fillna(df[col].median(),inplace=True)
for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0],inplace=True)
# Out:
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)
# C:\Users\ABISHEK\AppData\Local\Temp\ipykernel_17120\2911937469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(),inplace=True)

# %%
#step 4: Encode categorical features
label_encoders={}
for col in df.select_dtypes(include=['object']).columns:
    le=LabelEncoder()
    df[col] = le.fit_transform([col])
    label_encoders[col]

# %%
#step 5: feature selection 
target_columns = "price"
x = df.drop(target_columns, axis=1)
y = df[target_columns]

# %%
#step 6: feature scaling
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
#step 7: Train - test split
x_train, x_test, y_train, y_test = train_test_split(
    x_scaled,y, test_size=0.2, random_state=42
)

# %%
#helper function for evaluation
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    print("MAE:",mae)
    print("MSE:",mse)
    print("RMSE:",rmse)
    print("r2_score:", r2)

# %%
#linear regression 
print("\n===== Linear Regression =====")
lr= LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)
evaluate_model(y_test, y_pred)
# Out:
# ===== Linear Regression =====
# MAE: 210908.17325011524
# MSE: 986921767056.1313
# RMSE: 993439.3625461654
# r2_score: 0.03228385663277078

# %%
#multiple linear regression
print("\n===== Multiple Linear Regression =====")
mlr = LinearRegression()
mlr.fit(x_train, y_train) 
y_pred =mlr.predict(x_test)
evaluate_model(y_test, y_pred)
# Out:
# ===== Multiple Linear Regression =====
# MAE: 210908.17325011524
# MSE: 986921767056.1313
# RMSE: 993439.3625461654
# r2_score: 0.03228385663277078

# %%
#polynomial linear regression
print("\n===== Polynomial Regression =====")
poly = PolynomialFeatures(degree=2)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

poly_model = LinearRegression()
poly_model.fit(x_train_poly, y_train)
y_pred = poly_model.predict(x_test_poly)
evaluate_model(y_test, y_pred)
# Out:
# ===== Polynomial Regression =====
# MAE: 210235.0487292744
# MSE: 988094878516.0714
# RMSE: 994029.6165185781
# r2_score: 0.031133574071733117

# %%
#ridge regression
print("\n===== Ridge Regression =====")
ridge = Ridge(alpha=1.0)
ridge.fit(x_train, y_train)
y_pred = ridge.predict(x_test)
evaluate_model(y_test, y_pred)
# Out:
# ===== Ridge Regression =====
# MAE: 210898.90512265472
# MSE: 986909598350.2739
# RMSE: 993433.2379935121
# r2_score: 0.03229578853405746

# %%
#5.Lasso Regression
print("\n===== Lasso Regression =====")
laaso = Lasso(alpha=0.1)
laaso.fit(x_train, y_train)
y_pred = laaso.predict(x_test)
evaluate_model(y_test, y_pred)
# Out:
# ===== Lasso Regression =====
# MAE: 210908.18550816114
# MSE: 986921816586.7089
# RMSE: 993439.3874750029
# r2_score: 0.03228380806606468
# c:\Users\ABISHEK\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.068e+13, tolerance: 5.229e+10
#   model = cd_fast.enet_coordinate_descent(

# %%
#6. Elastic Net Regression
print("\n===== Elastic Net Regression =====")
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_net.fit(x_train, y_train)
y_pred = elastic_net.predict(x_test)
evaluate_model(y_test, y_pred)
# Out:
# ===== Elastic Net Regression =====
# MAE: 209600.5719708338
# MSE: 985067308140.5646
# RMSE: 992505.5708360354
# r2_score: 0.03410222754089087

# %%
#7. Decision Tree Regression
print("\n===== Decision Tree Regression =====")
dt = DecisionTreeRegressor(max_depth=5)
dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)
evaluate_model(y_test, y_pred)
# Out:
# ===== Decision Tree Regression =====
# MAE: 220660.23681708917
# MSE: 1022482296979.8318
# RMSE: 1011178.6671898452
# r2_score: -0.00258466083493758

# %%
#random forest regression
print("\n===== Random Forest Regressor =====")
rf = RandomForestRegressor(n_estimators=100, max_depth=5, random_state=42)
rf.fit(x_train, y_train)    
y_pred = rf.predict(x_test)
evaluate_model(y_test, y_pred)
# Out:
# ===== Random Forest Regressor =====
# MAE: 207209.07999219213
# MSE: 986590259966.475
# RMSE: 993272.5003575177
# r2_score: 0.03260891255210474

# %%
#support vector regression
print("\n===== Support Vector Regression =====")
svr = SVR(kernel='rbf', C=100, gamma='scale')
svr.fit(x_train, y_train)
y_pred = svr.predict(x_test)
evaluate_model(y_test, y_pred)
# Out:
# ===== Support Vector Regression =====
# MAE: 260059.5130513124
# MSE: 1029119064592.7275
# RMSE: 1014455.057946249
# r2_score: -0.009092276102086405

# %%
# k Nearest Neighbors Regression
print("\n===== K NN Regression =====")
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
evaluate_model(y_test, y_pred)
# Out:
# ===== K NN Regression =====
# MAE: 213912.73160179064
# MSE: 995518307796.4869
# RMSE: 997756.6375607265
# r2_score: 0.023854605673628626
